# %%
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\Users\\g6cor\\OneDrive\\Documentos\\GitHub_Repos\\Covid-Crime'

# %%
df_names=pd.read_csv('c:/Users/g6cor/OneDrive/Documentos/basic_info.csv')

# %%
df_names
# Out:
#        Unnamed: 0      ID                      Name  Age     Nationality  \
# 0               0  236988             Eddie Nketiah   22         England
# 1               1  225863          Olivier Boscagli   23          France
# 2               2  241721  Rafael da Conceição Leão   22        Portugal
# 3               3  224371              Jarrod Bowen   24         England
# 4               4  200104             Heung Min Son   28  Korea Republic
# ...           ...     ...                       ...  ...             ...
# 19820       20036  245534             Carl Spellman   18         England
# 19821       20037  245535         Abdulkadir Parmak   26          Turkey
# 19822       20038  245536             Andrea Errico   19           Italy
# 19823       20039  245540           Stratos Svarnas   23          Greece
# 19824       20097  259356        Carney Chukwuemeka   17         England
#
#        Overall  Potential                 Club              Contract   Value  \
# ...

# %%
df_names.head()
# Out:
#    Unnamed: 0      ID                      Name  Age     Nationality  Overall  \
# 0           0  236988             Eddie Nketiah   22         England       72
# 1           1  225863          Olivier Boscagli   23          France       77
# 2           2  241721  Rafael da Conceição Leão   22        Portugal       82
# 3           3  224371              Jarrod Bowen   24         England       79
# 4           4  200104             Heung Min Son   28  Korea Republic       89
#
#    Potential               Club     Contract   Value   Wage  Total stat
# 0         79            Arsenal  2016 ~ 2022   €4.8M   €45K        1698
# 1         82                PSV  2019 ~ 2025  €14.5M   €15K        1961
# 2         90           AC Milan  2019 ~ 2024  €68.5M   €52K        1959
# 3         82    West Ham United  2020 ~ 2025    €24M   €63K        1966
# 4         89  Tottenham Hotspur  2015 ~ 2025   €104M  €240K        2141

# %%
df_names.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Nationality', 'Overall',
#        'Potential', 'Club', 'Contract', 'Value', 'Wage', 'Total stat'],
#       dtype='object')

# %%
df_all_info=pd.read_csv('c:/Users/g6cor/OneDrive/Documentos/detailed_info.csv')

# %%
df_all_info.head(5)
# Out:
#    Unnamed: 0      ID  LS  ST  RS  LW  LF  CF  RF  RW  ...  Composure  \
# 0           0  236988  74  74  74  70  72  72  72  70  ...       68.0
# 1           1  225863  66  66  66  69  68  68  68  69  ...       77.0
# 2           2  241721  82  82  82  82  82  82  82  82  ...       81.0
# 3           3  224371  77  77  77  78  78  78  78  78  ...       75.0
# 4           4  200104  88  88  88  87  87  87  87  87  ...       89.0
#
#    Defensive Awareness  Standing Tackle  Sliding Tackle  GK Diving  \
# 0                 22.0               19              15         12
# 1                 76.0               78              77          8
# 2                 22.0               24              21         10
# 3                 49.0               40              36         14
# 4                 47.0               34              33         11
#
#    GK Handling  GK Kicking  GK Positioning  GK Reflexes  \
# 0           10          11               9            5
# ...

# %%
df_all_info.shape
# Out:
# (14705, 75)

# %%
df_names.shape
# Out:
# (19825, 12)
